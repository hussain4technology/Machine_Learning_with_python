# %%
print("pandas library is one of the most important library for data analysis")
# Out:
# pandas library is one of the most important library for data analysis

# %%
import pandas as pd

# %%
firstDataFrame=pd.DataFrame({'col1':[1,2],'col2':[3,4]});

# %%
firstDataFrame
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %%
print("you can also create a Dataframe using values from numpy array, that will discuss later, But for now let us see how to create random array through numpy")
# Out:
# you can also create a Dataframe using values from numpy array, that will discuss later, But for now let us see how to create random array through numpy

# %%
import numpy as np

# %%
m=np.random.randint(low=8,high=64,size=(6,5))

# %%
m
# Out:
# array([[48, 47, 61, 31, 22],
#        [53, 22, 16, 32, 45],
#        [38, 12, 53, 27, 59],
#        [49, 34, 57, 18, 33],
#        [54, 10, 54, 18, 36],
#        [29, 48, 24, 26, 34]])

# %%
print("Lets use these above array to create a dataFrame")
# Out:
# Lets use these above array to create a dataFrame

# %%
second_DataFrame=pd.DataFrame(m,columns=["Ae",'height','weight','RBS','FBS'])

# %%
second_DataFrame
# Out:
#    Ae  height  weight  RBS  FBS
# 0  48      47      61   31   22
# 1  53      22      16   32   45
# 2  38      12      53   27   59
# 3  49      34      57   18   33
# 4  54      10      54   18   36
# 5  29      48      24   26   34

# %%
#
